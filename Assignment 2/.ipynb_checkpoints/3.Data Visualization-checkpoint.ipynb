# %% [markdown]
# # Create visualizations using MatPlotLib and Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Admission.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
plt.scatter(df['GRE Score'],df['CGPA'])
plt.grid(True)
plt.title('Scatterplot of CGPA vs Gre score ')
plt.xlabel('GRE Score')
plt.ylabel('CGPA')
plt.show()

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
dt=pd.read_csv('Admission.csv')


def visualize_histogram(column_data):
    plt.figure(figsize=(8, 6))
    plt.hist(column_data, bins=20, edgecolor='k', alpha=0.7)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Histogram')
    plt.show()

def visualize_scatter(x_column,y_column):
    plt.figure(figsize=(8, 6))
    plt.scatter(data[x_column], data[y_column], alpha=0.5)
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title('Scatter Plot')
    plt.show()
    
# columns= dt.columns()
# print(columns)

#histogram
select_column=input('Enter the column name for histogram:')
if select_column in dt.columns:
    visualize_histogram(dt[select_column])
else:
    print('Column not found in dataset')
    
#scatterplot    
x_column = input("Enter the x-axis column name for scatter plot: ")
y_column = input("Enter the y-axis column name for scatter plot: ")

if x_column in dt.columns and y_column in dt.columns:
    visualize_scatter(x_column,ycolumn)
else:
    print("One or both columns not found in the dataset.")
# Out:
# Enter the column name for histogram:GRE Score
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 29
#      27 select_column=input('Enter the column name for histogram:')
#      28 if select_column in dt.columns:
# ---> 29     visualize_histogram(dt[select_column])
#      30 else:
#      31     print('Column not found in dataset')
#
# Cell In[13], line 8, in visualize_histogram(column_data)
#       7 def visualize_histogram(column_data):
# ----> 8     plt.figure(figsize=(8, 6))
#       9     plt.hist(column_data, bins=20, edgecolor='k', alpha=0.7)
#      10     plt.xlabel('Value')
#
# TypeError: 'module' object is not callable

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset

data = pd.read_csv('Admission.csv')

def visualize_histogram(column_data):
    plt.figure(figsize=(8, 6))
    plt.hist(column_data, bins=20, edgecolor='k', alpha=0.7)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Histogram')
    plt.show()

def visualize_scatter(x_column, y_column):
    plt.figure(figsize=(8, 6))
    plt.scatter(data[x_column], data[y_column], alpha=0.5)
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title('Scatter Plot')
    plt.show()

# Allow users to select columns and visualize data distributions using histograms
selected_column = input("Enter the column name for histogram: ")
if selected_column in data.columns:
    visualize_histogram(data[selected_column])
else:
    print("Column not found in the dataset.")

# Implement scatter plots for bivariate data visualization
x_column = input("Enter the x-axis column name for scatter plot: ")
y_column = input("Enter the y-axis column name for scatter plot: ")
if x_column in data.columns and y_column in data.columns:
    visualize_scatter(x_column, y_column)
else:
    print("One or both columns not found in the dataset.")
