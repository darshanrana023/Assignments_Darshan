# %% [markdown]
# # Create visualizations using MatPlotLib and Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Admission.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
plt.scatter(df['GRE Score'],df['CGPA'])
plt.grid(True)
plt.title('Scatterplot of CGPA vs Gre score ')
plt.xlabel('GRE Score')
plt.ylabel('CGPA')
plt.show()

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset

data = pd.read_csv('Admission.csv')

def visualize_histogram(column_data):
    plt.figure(figsize=(8, 6))
    plt.hist(column_data, bins=20, edgecolor='k', alpha=0.7)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Histogram')
    plt.show()

def visualize_scatter(x_column, y_column):
    plt.figure(figsize=(8, 6))
    plt.scatter(data[x_column], data[y_column], alpha=0.5)
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title('Scatter Plot')
    plt.show()

# Allow users to select columns and visualize data distributions using histograms
selected_column = input("Enter the column name for histogram: ")
if selected_column in data.columns:
    visualize_histogram(data[selected_column])
else:
    print("Column not found in the dataset.")

# Implement scatter plots for bivariate data visualization
x_column = input("Enter the x-axis column name for scatter plot: ")
y_column = input("Enter the y-axis column name for scatter plot: ")
if x_column in data.columns and y_column in data.columns:
    visualize_scatter(x_column, y_column)
else:
    print("One or both columns not found in the dataset.")
# Out:
# Enter the column name for histogram: GRE Score
# Enter the x-axis column name for scatter plot: GRE Score
# Enter the y-axis column name for scatter plot: University Rating

# %% [markdown]
# # Scatterplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('Admission.csv')

# Allow users to input the columns for the scatter plot
x_column = input("Enter the x-axis column name for the scatter plot: ")
y_column = input("Enter the y-axis column name for the scatter plot: ")

# Create a scatter plot using Matplotlib
plt.figure(figsize=(8, 6))
plt.scatter(data[x_column], data[y_column], alpha=0.5)
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Scatter Plot')
plt.show()

# Alternatively, create a scatter plot using Seaborn for enhanced styling
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x=x_column, y=y_column, alpha=0.5)
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Scatter Plot')
plt.show()
# Out:
# Enter the x-axis column name for the scatter plot: TOEFL Score
# Enter the y-axis column name for the scatter plot: CGPA

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
